# %%
import pandas as pd

df = pd.read_csv("netflix_titles.csv")

new_df = df.loc[df["country"] == 'Singapore']
sm_df = new_df.loc[df["type"] == "Movie"]
sm_df = sm_df.reset_index(drop=True)
#sm_df is singapore movies df

#sm_df = sm_df.loc[df["rating"]

sm_df
# Out:
#   show_id   type                           title       director  \
# 0      s3  Movie                           23:59   Gilbert Chan
# 1    s512  Movie          André & his olive tree      Josiah Ng
# 2   s2094  Movie      Fakkah Fuzz: Almost Banned  Michael McKay
# 3   s2957  Movie                       Imperfect    Steve Cheng
# 4   s3529  Movie                       Lang Tong        Sam Loh
# 5   s4139  Movie  Miss J Contemplates Her Choice      Jason Lai
#
#                                                 cast    country  \
# 0  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...  Singapore
# 1                                       André Chiang  Singapore
# 2                                        Fakkah Fuzz  Singapore
# 3  Edwin Goh, Ian Fang Weijie, Phua Yida, Kimberl...  Singapore
# 4  William Lawandi, Angeline Yap, Vivienne Tseng,...  Singapore
# 5  Kit Chan, Xiang Yun, Bobby Tonelli, Shane Pow,...  Singapore
#
#           date_added  release_year rating duration  \
# ...

# %%
index = ['TV-PG', 'TV-MA', 'R']
movies = [1, 4, 1]
sm_df = pd.DataFrame({'movies': movies}, index=index)


ax = sm_df.plot.bar(rot=0)
